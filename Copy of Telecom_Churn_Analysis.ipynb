# %% [markdown]
# # **Project Name**    - Telecom_Churn_Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** -Nikhil Nivas Patil

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Customer churn is a big problem in any industry and one of the most important concerns for the Telecom industry. The effect on the revenues of the companies, because of this customer churns is huge, especially in the telecom field, that's why these companies are seeking to develop a predictive potential customer churn. In this highly competitive market, the telecommunications industry experiences an average of 15-25% annual churn rate, and it costs 5-10 times more to acquire a new customer than to retain an existing one, that's why customer retention has now become even more important than customer acquisition.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/NikhilMITADT/Telecom_Churn_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Finding those factors that increase customer churn is important to take necessary actions to reduce this churn. The main goal of our project is to develop an understanding of the cause of customer churn which assists telecom operators to predict customers who are most likely subject to churn, and what to do to retain the most valuable customer.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Maximize: Company's profit by retaining customer
#
# Minimize: Customer churn by identifying the key cause of the problem

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
from io import IncrementalNewlineDecoder
# Import Libraries
import pandas as pd
import numpy as np
#visualization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
path='/content/drive/MyDrive/Almabetter/'
df=pd.read_csv(path + 'Telecom Churn.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isna().sum()
df.isnull().sum()

# %%
# Visualizing the missing values
missing=pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax=sns.pointplot('index',0,data=missing)
plt.xticks(rotation=90,fontsize=7)
plt.title('percentenge of missing values')
plt.ylabel('percentage')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# There are 3333 rows and 20 columns in above data set.
#
# 8 float data type.
#
# 8 int data type.
#
# 3 object data type.
#
# 1 boolen data type.
#
# there are no missing value and no duplicate values are present.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **State** - 51 unique states in Unnited States in America
#
# **Account Length** - Length of the Account
#
# **Area Code** - 415 relates to San Francisco, 408 is of San Jose and 510 is of City of Oakland
#
# **International Plane** - Yes indicates international plane is activate and No indicates international plane is not activate
#
# **VoceMail Plane** - yes indicates vocemail plane is activate and No indicates voicemail plane is not activate
#
# **Number vmail Massage** - No. of voice mail Massages Ranging from 0 to 50 Total Day Minutes
#
# **Total day minutes** - Total no. of minutes spend by customer in morning
#
# **Total Day Calls** - Total number of calls made by customer in morning
#
# **Total Day Charge** - total charge to custemers in morning
#
# **Total eve minutes** - Total no. of minutes spend by customer in evening
#
# **Total eve Calls** - Total number of calls made by customer in evening
#
# **Total eve Charge** - total charge to custemers in evening
#
# **Total night minutes** - Total no. of minutes spend by customer in night
#
# **Total night Calls** - Total number of calls made by customer in night
#
# **Total night Charge** - total charge to custemers in night

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()

# %%
df['Churn'].unique()

# %%
df['State'].unique()

# %%
df['Account length'].unique()

# %%
df['Area code'].unique()

# %%
df['International plan'].unique()

# %%
df['Voice mail plan'].unique()

# %% [markdown]
# ## ***4.  Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
# Analyzing What The Dependent Variable Said To Us i.e 'CHURN'.

# %%
# Chart - 1 visualization code
#To get the pie chart to analyze churn
df ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(8,8))
plt.title('Pie Chart for Churn')
plt.show()

# %% [markdown]
# Above pie chart is show that blue colour indicate flase Churn and orange colour is indicates True Churn.

# %% [markdown]
# Insight found from the above chart there are 85.5% are false churn and 14.5% are the true Churn.

# %% [markdown]
# *   Above pie chart shows Churn number of customer this shows that arround 15% coustomers are Churn

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
sns.countplot(x=df.Churn)

# %% [markdown]
# Above Bar chart is show that blue colour indicate flase Churn and orange colour is indicates True Churn.

# %% [markdown]
# Insight found from the above chart there are 85.5% are false churn and 14.5% are the true Churn.

# %% [markdown]
# #### Chart - 3
# #Comparison churn with state by using countplot

# %%
# Chart - 3 visualization code
a1=df['State'].unique()
plt.rcParams['figure.figsize']=(18,7)
a2=df.groupby(['State'])['Churn'].mean()
plt.plot(a1,a2,marker='o')
plt.title('State Churn rate')
plt.xlabel('State')
plt.ylabel('Churn Rate')
plt.show()

# %%
#comarison Churn With State by using countplot
sns.set(style='darkgrid')
plt.figure(figsize=(15,8))
x=sns.countplot(x='State',hue='Churn',data=df)
plt.show()

# %% [markdown]
# above graph is Comparison churn with state by using countplot which is show true churn and false churn

# %% [markdown]
# ##### Chart 5

# %% [markdown]
# Answer Here

# %%
# Chart - 4 visualization code


plt.rcParams['figure.figsize']=(18,7)
color=plt.cm.copper(np.linspace(0,0.5,20))
((df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending=False).head(6).plot.bar(color=['violet','indigo','b','g','y','orange','r'])
plt.title("States with most churn percentage")
plt.xlabel('State')
plt.ylabel('percentage')
plt.show()

# %% [markdown]
# *There is 51 unique state present who have different churn rate.*
#
# *From the above analysis CA, NJ, TX, MD, SC, MI are the ones who have a higher churn rate of more than 21.*
#
# *The reason for this churn rate from a particular state may be due to the low coverage of the cellular network.*

# %%
# Chart - 5 visualization code
a=sns.countplot(x='Area code',hue="Churn",data=df)
plt.show()

# %% [markdown]
# *In the above data, we notice that there is only 3 unique value are there i.e408,415,510 and the churn rate of these area codes are almost same.*
#
# *we don't think there is any kind of relation present between the "area code" and"churn" due to which the customer leaves the operator.*

# %% [markdown]
# #### Chart - 6
# Analyzing "International Plan" column

# %%
# Chart - 6 visualization code
#To get the Donut Plot to analyze International Plan
data = df['International plan'].value_counts()
explode = (0, 0.2)
plt.pie(data, explode = explode,autopct='%1.1f%%',shadow=True,radius = 2.0, labels = ['No','Yes'],colors=['skyblue' ,'orange'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title('Donut Plot for International plan')
plt.show()

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
#Analysing by using countplot
sns.countplot(x='International plan',hue="Churn",data = df)

# %% [markdown]
# *From the above data we get*
#
# *There are 3010 customers who dont have a international plan.*
#
# *There are 323 customers who have a international plan.*

# %% [markdown]
# *Among those who have a international plan 42.4 % people churn.*
#
# *Whereas among those who dont have a international plan only 11.4 % people churn.*

# %% [markdown]
# *So basically the people who bought International plans are churning in big numbers.*
#
# *Probably because of connectivity issues or high call charge.*

# %% [markdown]
# #### Chart - 8
# Analyzing "Voice Mail Plan" column

# %%
# Chart - 8 visualization code
#To get the Donut Plot to analyze Voice mail plan
data = df['Voice mail plan'].value_counts()
explode = (0, 0.2)
plt.pie(data, explode = explode,autopct='%1.1f%%',startangle=90,shadow=True,radius = 2.0, labels = ['NO','YES'],colors=['skyblue','red'])
circle = plt.Circle( (0,0), 1, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.title('Donut Plot for Voice mail plan')
plt.show()

# %% [markdown]
# *As we can see there is are no clear relation between voice mail plan and churn so we can't clearly say anything so let's move to the next voice mail feature i.e number of voice mail, let's see what it gives to us.*

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
#Analysing by using countplot
sns.countplot(x='Voice mail plan',hue="Churn",data =df)

# %% [markdown]
# *As we can see there is are no clear relation between voice mail plan and churn so we can't clearly say anything so let's move to the next voice mail feature i.e number of voice mail, let's see what it gives to us.*

# %% [markdown]
# #### Chart - 10
# relation between overall call charge

# %%
# Chart - 10 visualization code
#Deriving a relation between overall call charge and overall call minutes 
day_charge_perm = df['Total day charge'].mean()/df['Total day minutes'].mean()
eve_charge_perm = df['Total eve charge'].mean()/df['Total eve minutes'].mean()
night_charge_perm = df['Total night charge'].mean()/df['Total night minutes'].mean()
int_charge_perm= df['Total intl charge'].mean()/df['Total intl minutes'].mean()
sns.barplot(x=['Day','Evening','Night','International'],y=[day_charge_perm,eve_charge_perm,night_charge_perm,int_charge_perm])

# %% [markdown]
# *After analyzing the above dataset we have noticed that total day/night/eve minutes/call/charges are not put any kind of cause for churn rate. But international call charges are high as compare to others it's an obvious thing but that may be a cause for international plan customers to churn out.*

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
## plot the Correlation matrix
plt.figure(figsize=(17,8))
correlation=df.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')

# %% [markdown]
# here most of the variable have less correlation

# %% [markdown]
# above correlation matrix indicate that if there total minutes increases then charge also increase.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# *After performing exploratory data analysis on the data set, this is what we have incurred from data:*
#
# *There are some states where the churn rate is high as compared to others may be due to low network coverage.*
# **Area code and Account length do not play any kind of role regarding the churn rate so,it's redundant data columns* **In the International plan those customers who have this plan are churn more and also the international calling charges are also high so the customer who has the plan unsatisfied with network issues and high call charge* **IN the voice mail section when there are more than 20 voice-mail messages then there is a churn so it basically means that the quality of voice mail is not good. *Total day call minutes, total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, these columns didn't play any kind of role regarding the churn rate.* **In international calls data shows that the churn rate of those customers is high, those who take the international plan so it means that in international call charges are high also there is a call drop or network issue.* **In Customer service calls data shows us that whenever an unsatisfied customer called the service center the churn rate is high, which means the service center didn't resolve the customer issue.*

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *Improve network coverage churned state*
#
# *In international plan provide some discount plan to the customer*
#
# *Improve the voice mail quality or take feedback from the customer*
#
# *Improve the service of call center and take frequently feedback from the customer regarding their issue and try to solve it as soon as possible*
